# %%
a=2
b=3
print(a**b)
# Out:
# 8

# %%
a=10
b=20
a=a+b#30
b=a-b#30-20=10
a=a-b#30-10=20
print("a=", a)
print("b=",b)
# Out:
# a= 20
# b= 10

# %%
a=10
b=20
print("a=", b)
print("b=", a)
# Out:
# a= 20
# b= 10

# %%
a=456
u=a%10
t=(a//10)%10#45%10
print("unitdigit=",u)
print("tendigit=",t)
# Out:
# unitdigit= 6
# tendigit= 5

# %%
#ASSIGNMENT OPERATORS
a=10
a+=10
#print(a)

a=56
a-=56
#print(a)

a=20
a*=20
#print(a)

a=36
a//=36
print(a)
# Out:
# 1

# %%
#RELATIONAL OPERATORS
a=10
b=5
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# True
# False

# %%
#ASCII VALUES
#A=65,B=66,C=67....Z
#a=97,b=98,c=99...z
#0=48,1=49,2=50...9
print("A")
# Out:
# A

# %%
#ASCII VALUES
a="abc"#97
b="abcd"#65
print(a>b)
# Out:
# False

# %%
#ASCII VALUE
a="100"
b="20"
print(a>b)#1>2 49>50
# Out:
# False

# %%
#Logical Operators-->handle multiple conditions
#AND,OR,NOT
#AND--> returns false if any one condition is false
#OR--> returns true if any one condition is true
#NOT--> Opposite of trur or false

# %%
#LOGICAL OPERATORS
a=7
b=5
print(a>b and b>10)
# Out:
# False

# %%
a=7
b=5
print(not(a>b))
# Out:
# False

# %%
#and have high precedence than or
print(5>2 and 10>3 or 1>5)
#     True and True or False
#          True or False
#               True
# Out:
# True
